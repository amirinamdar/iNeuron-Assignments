# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
#
# **ans**
# # *	      ➡   expression
# #'hello'	➡	value
# # -87.8	  ➡	value
# # -       ➡ expression
# # /		    ➡	expression
# # +			  ➡ expression
# # 6 	    ➡	value

# %% [markdown]
# 2. What is the difference between string and variable?
#
# **ans**
# Variable is a container for store a information or data.
# String is type of an information or data, so we can use it to fillup the variable.

# %% [markdown]
# 3. Describe three different data types.
#
# **ans**
# int =  It stores the integers values that can be positive or negative and do not contain any decimal point. e.g. :– a=3, b=12
#
# string = A string is a sequence of characters enclosed in single quotes double quotes or triple quotes. e.g. :- x= "My name is Amir", y='ineuron'
#
# boolean = A boolean data type is declared with the bool keyword and can only take the values true or false. When the value is returned, true = 1 and false = 0.

# %% [markdown]
# 4. What is an expression made up of? What do all expressions do?
#
# **ans**
# Expression is made up of values, containers, and mathematical operators (operands) e.g
#      a = 9 + 5     and expressions are used to evaluate the values or represent the result on the screen.

# %% [markdown]
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
# **ans** An expression is a combination of operators and operands that is interpreted to produce some other value and the statement is just like a command that a python interpreter executes like print.

# %% [markdown]
# 6. After running the following code, what does the variable bacon contain?
#
# bacon = 22
#
# bacon + 1
#
# **ans** It gives 23 as execution code ![image.png](data:image/png;base64,...)

# %% [markdown]
# 7. What should the values of the following two terms be?
#
# 'spam' + 'spamspam'
#
# 'spam' * 3
#
# **ans** it will be the same
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 8. Why is eggs a valid variable name while 100 is invalid?
#
# **ans** because we can't start giving variable an integer name. if we, we should begin with, a string-like alphabet name then integer. e100 or eggs100 is valid

# %% [markdown]
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
# **ans** str(), int(), float()

# %% [markdown]
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten' + 99 + 'burritos'
# **ans** because 99 is an integer it cannot be concatenated with strings, if we have to concatenate it we need to do typecasting.
